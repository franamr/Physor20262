# %%
from NeutronTransportSolver import NeutronTransportSolver

# %%
from dolfinx import mesh, fem, default_scalar_type
from mpi4py import MPI
import numpy as np
import time

# %%
print('------------------------------------------------------------------------------')
# Crear el dominio
domain = mesh.create_unit_square(MPI.COMM_WORLD, 16, 16)

# Crear el solver y resolver 
solver = NeutronTransportSolver(domain, bord_cond = 'dir')
time0 = time.process_time()
solver.solve()
time1 = time.process_time()

print('16 x 36 Unit square')
print('k_eff                                                   :', solver.eigval)
print('Number of iterations Dynamic Power Method with momentum :', solver.power_its)
print('CPU time                                                :', time1 - time0)

print('------------------------------------------------------------------------------')
# Crear el dominio
domain = mesh.create_unit_square(MPI.COMM_WORLD, 32, 32)
# Crear el solver y resolver 
solver = NeutronTransportSolver(domain,bord_cond = 'dir')
time0 = time.process_time()
solver.solve()
time1 = time.process_time()
print('32 x 32 Unit square')
print('k_eff                                                   :', solver.eigval)
print('Number of iterations Dynamic Power Method with momentum :', solver.power_its)
print('CPU time                                                :', time1 - time0)

print('------------------------------------------------------------------------------')
# Crear el dominio
domain = mesh.create_unit_square(MPI.COMM_WORLD, 64, 64)

# Crear el solver y resolver 
solver = NeutronTransportSolver(domain,bord_cond = 'dir')
time0 = time.process_time()

solver.solve()
time1 = time.process_time()

print('64 x 64 Unit square')
print('k_eff                                                   :', solver.eigval)
print('Number of iterations Dynamic Power Method with momentum :', solver.power_its)
print('CPU time                                                :', time1 - time0)

print('------------------------------------------------------------------------------')
# Crear el dominio
domain = mesh.create_unit_square(MPI.COMM_WORLD, 128, 128)

#Crear el solver y resolver 
solver = NeutronTransportSolver(domain,bord_cond = 'dir')
time0 = time.process_time()
solver.solve()
time1 = time.process_time()

print('------------------------------------------------------------------------------')
print('64 x 64 Unit square')
print('k_eff                                                   :', solver.eigval)
print('Number of iterations Dynamic Power Method with momentum :', solver.power_its)
print('CPU time                                                 :', time1 - time0)
# Out:
# ------------------------------------------------------------------------------
# prom iteraciones gmres:  3.0
# 16 x 36 Unit square
# k_eff                                                   : 0.014878728588938975
# Number of iterations Dynamic Power Method with momentum : 5
# CPU time                                                : 0.06935258099999997
# ------------------------------------------------------------------------------
# prom iteraciones gmres:  3.0
# 32 x 32 Unit square
# k_eff                                                   : 0.01498497026474536
# Number of iterations Dynamic Power Method with momentum : 4
# CPU time                                                : 0.06086331899999964
# ------------------------------------------------------------------------------
# prom iteraciones gmres:  3.0
# 64 x 64 Unit square
# k_eff                                                   : 0.015011731062353477
# Number of iterations Dynamic Power Method with momentum : 4
# CPU time                                                : 0.10070869400000015
# ------------------------------------------------------------------------------
# prom iteraciones gmres:  3.0
# ------------------------------------------------------------------------------
# 64 x 64 Unit square
# k_eff                                                   : 0.015017572255188953
# Number of iterations Dynamic Power Method with momentum : 3
# CPU time                                                 : 2.457990977

# %%
print('Dynamic momentum power method')
print('------------------------------------------------------------------------------')

print('16 x 16 Unit square')
# Crear el dominio
domain = mesh.create_unit_square(MPI.COMM_WORLD, 16, 16)

# Crear el solver y resolver 
solver = NeutronTransportSolver(domain, bord_cond = 'rob', power_tol=1e-6, ksp_tol=1e-7)
time0 = time.process_time()
solver.solve()
time1 = time.process_time()


print('k_eff                                                   :', solver.eigval)
print('Number of iterations Dynamic Power Method with momentum :', solver.power_its)
print('CPU time                                                :', time1 - time0)

print('------------------------------------------------------------------------------')
print('32 x 32 Unit square')
# Crear el dominio
domain = mesh.create_unit_square(MPI.COMM_WORLD, 32, 32)
# Crear el solver y resolver 
solver = NeutronTransportSolver(domain,bord_cond = 'rob',  power_tol=1e-6, ksp_tol=1e-7)
time0 = time.process_time()
solver.solve()
time1 = time.process_time()

print('k_eff                                                   :', solver.eigval)
print('Number of iterations Dynamic Power Method with momentum :', solver.power_its)
print('CPU time                                                :', time1 - time0)

print('------------------------------------------------------------------------------')
print('64 x 64 Unit square')
# Crear el dominio
domain = mesh.create_unit_square(MPI.COMM_WORLD, 64, 64)

# Crear el solver y resolver 
solver = NeutronTransportSolver(domain,bord_cond = 'rob',  power_tol=1e-6, ksp_tol=1e-7)
time0 = time.process_time()

solver.solve()
time1 = time.process_time()

print('k_eff                                                   :', solver.eigval)
print('Number of iterations Dynamic Power Method with momentum :', solver.power_its)
print('CPU time                                                :', time1 - time0)

print('------------------------------------------------------------------------------')
print('128 x 128 Unit square')
# Crear el dominio
domain = mesh.create_unit_square(MPI.COMM_WORLD, 128, 128)

#Crear el solver y resolver 
solver = NeutronTransportSolver(domain,bord_cond = 'rob',  power_tol=1e-6, ksp_tol=1e-7)
time0 = time.process_time()
solver.solve()
time1 = time.process_time()

#print('------------------------------------------------------------------------------')

print('k_eff                                                   :', solver.eigval)
print('Number of iterations Dynamic Power Method with momentum :', solver.power_its)
print('CPU time                                                 :', time1 - time0) 
print('------------------------------------------------------------------------------')
print('256 x 256 Unit square')
# Crear el dominio
domain = mesh.create_unit_square(MPI.COMM_WORLD, 256, 256)

#Crear el solver y resolver 
solver = NeutronTransportSolver(domain,bord_cond = 'rob',  power_tol=1e-6, ksp_tol=1e-7)
time0 = time.process_time()
solver.solve()
time1 = time.process_time()

#print('------------------------------------------------------------------------------')

print('k_eff                                                   :', solver.eigval)
print('Number of iterations Dynamic Power Method with momentum :', solver.power_its)
print('CPU time                                                 :', time1 - time0) 
print('------------------------------------------------------------------------------')
print('512 x 512 Unit square')
# Crear el dominio
domain = mesh.create_unit_square(MPI.COMM_WORLD, 512, 512)

#Crear el solver y resolver 
solver = NeutronTransportSolver(domain,bord_cond = 'rob',  power_tol=1e-6, ksp_tol=1e-7)
time0 = time.process_time()
solver.solve()
time1 = time.process_time()

#print('------------------------------------------------------------------------------')

print('k_eff                                                   :', solver.eigval)
print('Number of iterations Dynamic Power Method with momentum :', solver.power_its)
print('CPU time                                                 :', time1 - time0)
# Out:
# Dynamic momentum power method
# ------------------------------------------------------------------------------
# 16 x 16 Unit square
# prom iteraciones gmres:  4.0
# k_eff                                                   : 0.14876468354097216
# Number of iterations Dynamic Power Method with momentum : 3
# CPU time                                                : 0.08936413000000032
# ------------------------------------------------------------------------------
# 32 x 32 Unit square
# prom iteraciones gmres:  4.0
# k_eff                                                   : 0.14879297110505785
# Number of iterations Dynamic Power Method with momentum : 3
# CPU time                                                : 0.16951392499999995
# ------------------------------------------------------------------------------
# 64 x 64 Unit square
# prom iteraciones gmres:  4.0
# k_eff                                                   : 0.14880007812817395
# Number of iterations Dynamic Power Method with momentum : 3
# CPU time                                                : 0.43720999699999963
# ------------------------------------------------------------------------------
# 128 x 128 Unit square
# prom iteraciones gmres:  4.0
# k_eff                                                   : 0.1488018575011205
# Number of iterations Dynamic Power Method with momentum : 3
# CPU time                                                 : 14.226812476
# ------------------------------------------------------------------------------
# 256 x 256 Unit square
# prom iteraciones gmres:  4.0
# k_eff                                                   : 0.14880230250762844
# Number of iterations Dynamic Power Method with momentum : 3
# CPU time                                                 : 15.828318406999998
# ------------------------------------------------------------------------------
# 512 x 512 Unit square
# k_eff                                                   : 0.14880238137140434
# Number of iterations Dynamic Power Method with momentum : 2
# CPU time                                                 : 24.241210349

# %%
print('Dynamic momentum power method')
print('------------------------------------------------------------------------------')

print('16 x 16 Unit square')
# Crear el dominio
domain = mesh.create_unit_square(MPI.COMM_WORLD, 16, 16)

# Crear el solver y resolver 
solver = NeutronTransportSolver(domain, bord_cond = 'rob', power_tol=1e-6, ksp_tol=1e-7)
time0 = time.process_time()
solver.solve()
time1 = time.process_time()


print('k_eff                                                   :', solver.eigval)
print('Number of iterations Dynamic Power Method with momentum :', solver.power_its)
print('CPU time                                                :', time1 - time0)

print('------------------------------------------------------------------------------')
print('32 x 32 Unit square')
# Crear el dominio
domain = mesh.create_unit_square(MPI.COMM_WORLD, 32, 32)
# Crear el solver y resolver 
solver = NeutronTransportSolver(domain,bord_cond = 'rob',  power_tol=1e-6, ksp_tol=1e-7)
time0 = time.process_time()
solver.solve()
time1 = time.process_time()

print('k_eff                                                   :', solver.eigval)
print('Number of iterations Dynamic Power Method with momentum :', solver.power_its)
print('CPU time                                                :', time1 - time0)

print('------------------------------------------------------------------------------')
print('64 x 64 Unit square')
# Crear el dominio
domain = mesh.create_unit_square(MPI.COMM_WORLD, 64, 64)

# Crear el solver y resolver 
solver = NeutronTransportSolver(domain,bord_cond = 'rob',  power_tol=1e-6, ksp_tol=1e-7)
time0 = time.process_time()

solver.solve()
time1 = time.process_time()

print('k_eff                                                   :', solver.eigval)
print('Number of iterations Dynamic Power Method with momentum :', solver.power_its)
print('CPU time                                                :', time1 - time0)

print('------------------------------------------------------------------------------')
print('128 x 128 Unit square')
# Crear el dominio
domain = mesh.create_unit_square(MPI.COMM_WORLD, 128, 128)

#Crear el solver y resolver 
solver = NeutronTransportSolver(domain,bord_cond = 'rob',  power_tol=1e-6, ksp_tol=1e-7)
time0 = time.process_time()
solver.solve()
time1 = time.process_time()

#print('------------------------------------------------------------------------------')

print('k_eff                                                   :', solver.eigval)
print('Number of iterations Dynamic Power Method with momentum :', solver.power_its)
print('CPU time                                                 :', time1 - time0) 
print('------------------------------------------------------------------------------')
print('256 x 256 Unit square')
# Crear el dominio
domain = mesh.create_unit_square(MPI.COMM_WORLD, 256, 256)

#Crear el solver y resolver 
solver = NeutronTransportSolver(domain,bord_cond = 'rob',  power_tol=1e-6, ksp_tol=1e-7)
time0 = time.process_time()
solver.solve()
time1 = time.process_time()

#print('------------------------------------------------------------------------------')

print('k_eff                                                   :', solver.eigval)
print('Number of iterations Dynamic Power Method with momentum :', solver.power_its)
print('CPU time                                                 :', time1 - time0) 
print('------------------------------------------------------------------------------')
print('512 x 512 Unit square')
# Crear el dominio
domain = mesh.create_unit_square(MPI.COMM_WORLD, 512, 512)

#Crear el solver y resolver 
solver = NeutronTransportSolver(domain,bord_cond = 'rob',  power_tol=1e-6, ksp_tol=1e-7)
time0 = time.process_time()
solver.solve()
time1 = time.process_time()

#print('------------------------------------------------------------------------------')

print('k_eff                                                   :', solver.eigval)
print('Number of iterations Dynamic Power Method with momentum :', solver.power_its)
print('CPU time                                                 :', time1 - time0)
# Out:
# Dynamic momentum power method
# ------------------------------------------------------------------------------
# 16 x 16 Unit square
# prom iteraciones gmres:  4.0
# k_eff                                                   : 0.14876468354097216
# Number of iterations Dynamic Power Method with momentum : 3
# CPU time                                                : 0.037379250999947544
# ------------------------------------------------------------------------------
# 32 x 32 Unit square
# prom iteraciones gmres:  4.0
# k_eff                                                   : 0.14879297110505785
# Number of iterations Dynamic Power Method with momentum : 3
# CPU time                                                : 0.03792628700000478
# ------------------------------------------------------------------------------
# 64 x 64 Unit square
# prom iteraciones gmres:  4.0
# k_eff                                                   : 0.14880007812817395
# Number of iterations Dynamic Power Method with momentum : 3
# CPU time                                                : 0.08858711100003802
# ------------------------------------------------------------------------------
# 128 x 128 Unit square
# prom iteraciones gmres:  4.0
# k_eff                                                   : 0.1488018575011205
# Number of iterations Dynamic Power Method with momentum : 3
# CPU time                                                 : 2.7212495350000836
# ------------------------------------------------------------------------------
# 256 x 256 Unit square
# prom iteraciones gmres:  4.0
# k_eff                                                   : 0.14880230250762844
# Number of iterations Dynamic Power Method with momentum : 3
# CPU time                                                 : 7.992053103999979
# ------------------------------------------------------------------------------
# 512 x 512 Unit square
# k_eff                                                   : 0.14880238137140434
# Number of iterations Dynamic Power Method with momentum : 2
# CPU time                                                 : 15.432277811999938

# %%
print('SLEPC')
# Crear el dominio
domain = mesh.create_unit_square(MPI.COMM_WORLD, 16, 16)

# Crear el solver y resolver 
solver = NeutronTransportSolver(domain, eigmethod='slepc',bord_cond = 'rob')
time0 = time.process_time()
solver.solve()
time1 = time.process_time()

print('------------------------------------------------------------------------------')
print('16 x 16 Unit square')
print('k_eff                                                   :', 1/solver.eigval.real)
print('CPU time                                                :', time1 - time0)

# Crear el dominio
domain = mesh.create_unit_square(MPI.COMM_WORLD, 32, 32)

# Crear el solver y resolver 
solver = NeutronTransportSolver(domain, eigmethod='slepc',bord_cond = 'rob')
time0 = time.process_time()
solver.solve()
time1 = time.process_time()

print('------------------------------------------------------------------------------')
print('32 x 32 Unit square')
print('k_eff                                                   :', 1/solver.eigval.real)
print('CPU time                                                :', time1 - time0)

# Crear el dominio
domain = mesh.create_unit_square(MPI.COMM_WORLD, 64, 64)

# Crear el solver y resolver 
solver = NeutronTransportSolver(domain, eigmethod='slepc',bord_cond = 'rob')
time0 = time.process_time()
solver.solve()
time1 = time.process_time()

print('------------------------------------------------------------------------------')
print('64 x 64 Unit square')
print('k_eff                                                   :', 1/solver.eigval.real)
print('CPU time                                                :', time1 - time0)

# Crear el dominio
domain = mesh.create_unit_square(MPI.COMM_WORLD, 128, 128)

# Crear el solver y resolver 
solver = NeutronTransportSolver(domain, eigmethod='slepc',bord_cond = 'rob')
time0 = time.process_time()
solver.solve()
time1 = time.process_time()

print('------------------------------------------------------------------------------')
print('128 x 128 Unit square')
print('k_eff                                                   :', 1/solver.eigval.real)
print('CPU time                                                :', time1 - time0)
# Crear el dominio
domain = mesh.create_unit_square(MPI.COMM_WORLD, 256, 256)

# Crear el solver y resolver 
solver = NeutronTransportSolver(domain, eigmethod='slepc',bord_cond = 'rob')
time0 = time.process_time()
solver.solve()
time1 = time.process_time()

print('------------------------------------------------------------------------------')
print('256 x 256 Unit square')
print('k_eff                                                   :', 1/solver.eigval.real)
print('CPU time                                                :', time1 - time0)
# Crear el dominio
domain = mesh.create_unit_square(MPI.COMM_WORLD, 512, 512)

# Crear el solver y resolver 
solver = NeutronTransportSolver(domain, eigmethod='slepc',bord_cond = 'rob')
time0 = time.process_time()
solver.solve()
time1 = time.process_time()

print('------------------------------------------------------------------------------')
print('512 x 512 Unit square')
print('k_eff                                                   :', 1/solver.eigval.real)
print('CPU time                                                :', time1 - time0)
# Out:
# SLEPC
# ------------------------------------------------------------------------------
# 16 x 16 Unit square
# k_eff                                                   : 0.14876468310343474
# CPU time                                                : 0.12245925799999924
# ------------------------------------------------------------------------------
# 32 x 32 Unit square
# k_eff                                                   : 0.14879297086557156
# CPU time                                                : 0.3413596040000044
# ------------------------------------------------------------------------------
# 64 x 64 Unit square
# k_eff                                                   : 0.14880007806196263
# CPU time                                                : 1.0707670070000006
# ------------------------------------------------------------------------------
# 128 x 128 Unit square
# k_eff                                                   : 0.1488018575152364
# CPU time                                                : 3.3167891129999987
# ------------------------------------------------------------------------------
# 256 x 256 Unit square
# k_eff                                                   : 0.14880230257267832
# CPU time                                                : 11.641480114999993
# ------------------------------------------------------------------------------
# 512 x 512 Unit square
# k_eff                                                   : 0.14880241382308929
# CPU time                                                : 86.037714012

# %%
# Crear el dominio
domain = mesh.create_unit_cube(MPI.COMM_WORLD, 16, 16, 16)

# Crear el solver y resolver 
print('------------------------------------------------------------------------------')
print('16 x 16 x16 Unit cube')
solver = NeutronTransportSolver(domain, bord_cond='rob',  power_tol=1e-6, ksp_tol=1e-7)
time0 = time.process_time()
solver.solve()
time1 = time.process_time()


print('k_eff                                                   :', solver.eigval)
print('Number of iterations Dynamic Power Method with momentum :', solver.power_its)
print('CPU time                                                :', time1 - time0)

# Crear el dominio
domain = mesh.create_unit_cube(MPI.COMM_WORLD, 32, 32, 32)

print('------------------------------------------------------------------------------')
print('32 x 32 x 32 Unit cube')
# Crear el solver y resolver 
solver = NeutronTransportSolver(domain,bord_cond='rob',  power_tol=1e-6, ksp_tol=1e-7)
time0 = time.process_time()
solver.solve()
time1 = time.process_time()


print('k_eff                                                   :', solver.eigval)
print('Number of iterations Dynamic Power Method with momentum :', solver.power_its)
print('CPU time                                                :', time1 - time0)

# Crear el dominio
domain = mesh.create_unit_cube(MPI.COMM_WORLD, 64, 64, 64)

print('------------------------------------------------------------------------------')
print('64 x 64 x 64 Unit cube')
# Crear el solver y resolver 
solver = NeutronTransportSolver(domain,bord_cond='rob',  power_tol=1e-6, ksp_tol=1e-7)
time0 = time.process_time()
solver.solve()
time1 = time.process_time()


print('k_eff                                                   :', solver.eigval)
print('Number of iterations Dynamic Power Method with momentum :', solver.power_its)
print('CPU time                                               :', time1 - time0)
# Out:
# ------------------------------------------------------------------------------
# 16 x 16 x16 Unit cube
# prom iteraciones gmres:  4.0
# k_eff                                                   : 0.10390847221215804
# Number of iterations Dynamic Power Method with momentum : 3
# CPU time                                                : 0.6553168359999972
# ------------------------------------------------------------------------------
# 32 x 32 x 32 Unit cube
# prom iteraciones gmres:  4.0
# k_eff                                                   : 0.10392906266297997
# Number of iterations Dynamic Power Method with momentum : 3
# CPU time                                                : 20.826854225999995
# ------------------------------------------------------------------------------
# 64 x 64 x 64 Unit cube
# prom iteraciones gmres:  4.0
# k_eff                                                   : 0.10393426214018733
# Number of iterations Dynamic Power Method with momentum : 3
# CPU time                                               : 88.66863184900001

# %%
# Crear el dominio
domain = mesh.create_unit_cube(MPI.COMM_WORLD, 16, 16, 16)

# Crear el solver y resolver 
print('------------------------------------------------------------------------------')
print('16 x 16 x16 Unit cube')
solver = NeutronTransportSolver(domain, bord_cond='rob', eigmethod = 'slepc')
time0 = time.process_time()
solver.solve()
time1 = time.process_time()


print('k_eff                                                   :', 1/solver.eigval.real)
print('CPU time                                                :', time1 - time0)

# Crear el dominio
domain = mesh.create_unit_cube(MPI.COMM_WORLD, 32, 32, 32)

print('------------------------------------------------------------------------------')
print('32 x 32 x 32 Unit cube')
# Crear el solver y resolver 
solver = NeutronTransportSolver(domain,bord_cond='rob',  eigmethod = 'slepc')
time0 = time.process_time()
solver.solve()
time1 = time.process_time()


print('k_eff                                                   :', 1/solver.eigval.real)
print('CPU time                                                :', time1 - time0)
# Out:
# ------------------------------------------------------------------------------
# 16 x 16 x16 Unit cube
# k_eff                                                   : 0.10390847249142177
# CPU time                                                : 11.357247726000026
# ------------------------------------------------------------------------------
# 32 x 32 x 32 Unit cube
# k_eff                                                   : 0.10392906305270497
# CPU time                                                : 214.71693580400006

# %%
domain = mesh.create_unit_square(MPI.COMM_WORLD, 32, 32)
# Crear el solver y resolver 
solver = NeutronTransportSolver(domain,bord_cond = 'rob')
time0 = time.process_time()
solver.solve()
# Out:
# prom iteraciones gmres:  3.0

# %%
import matplotlib.pyplot as plt

# %%
plt.semilogy(solver.power_res, '-o')

# %%
domain = mesh.create_unit_square(MPI.COMM_WORLD, 16, 16)
#Crear el solver y resolver 
solver = NeutronTransportSolver(domain,bord_cond = 'dir')
time0 = time.process_time()
solver.solve()
time1 = time.process_time()

print('------------------------------------------------------------------------------')
print('64 x 64 Unit square')
print('k_eff                                                   :', solver.eigval)
print('Number of iterations Dynamic Power Method with momentum :', solver.power_its)
print('CPU time                                                 :', time1 - time0)
# Out:
# prom iteraciones gmres:  14.0
# ------------------------------------------------------------------------------
# 64 x 64 Unit square
# k_eff                                                   : 0.014878728252775981
# Number of iterations Dynamic Power Method with momentum : 5
# CPU time                                                 : 0.25875441999999893

# %%
import matplotlib.pyplot as plt

# %%
solver.power_its
# Out:
# 5

# %%
plt.semilogy(solver.power_res, 'o-')
plt.title('Resquare 16x16 (rtol=1e-6, gmres')
# Out:
# Text(0.5, 1.0, 'Resquare 16x16 (rtol=1e-6, gmres')

# %%
plt.semilogy(solver.power_res, 'o-')
plt.title('Resquare 16x16 (rtol=1e-8, gmres')
# Out:
# Text(0.5, 1.0, 'Residual square 16x16 (rtol=1e-8, gmres')

# %%
import gmsh
from dolfinx import io
gmsh.initialize()
gmsh.model.add("circle")
gmsh.model.occ.addDisk(0, 0, 0, 1, 1)
gmsh.model.occ.synchronize()

gmsh.model.addPhysicalGroup(2, [1], tag=1)
gmsh.model.setPhysicalName(2, 1, "circle")

gmsh.option.setNumber("Mesh.MeshSizeMax", 1/16)
gmsh.option.setNumber("Mesh.MeshSizeMin", 1/16)

gmsh.model.mesh.generate(2)

domain, _, _ = io.gmshio.model_to_mesh(
    gmsh.model, MPI.COMM_WORLD, 0, gdim=2)
gmsh.finalize()
# Out:
# Warning : Gmsh has aleady been initialized
# Info    : Meshing 1D...
# Info    : Meshing curve 1 (Ellipse)
# Info    : Done meshing 1D (Wall 0.00405926s, CPU 0.006669s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.487408s, CPU 0.496528s)
# Info    : 1011 nodes 2021 elements

# %%
#domain = mesh.create_rectangle(MPI.COMM_WORLD, [(0,0), (3,1)],(20,10))
#mesh.create_rectangle(MPI.COMM_WORLD, [(0,0), (2,1)],(20,10))
# Crear el solver y resolver 
solver = NeutronTransportSolver(domain, bord_cond = 'dir')
time0 = time.process_time()
solver.solve()
time1 = time.process_time()

print('------------------------------------------------------------------------------')
print('64 x 64 Unit square')
print('k_eff                                                   :', solver.eigval)
print('Number of iterations Dynamic Power Method with momentum :', solver.power_its)
print('CPU time                                                 :', time1 - time0)
# Out:
# prom iteraciones gmres:  21.0
# ------------------------------------------------------------------------------
# 64 x 64 Unit square
# k_eff                                                   : 0.049799018536019035
# Number of iterations Dynamic Power Method with momentum : 13
# CPU time                                                 : 1.0481341969998539

# %%
print('------------------------------------------------------------------------------')
# Crear el dominio
domain = mesh.create_unit_cube(MPI.COMM_WORLD, 8,8, 8)

#Crear el solver y resolver 
solver = NeutronTransportSolver(domain,bord_cond = 'dir')
time0 = time.process_time()
solver.solve()
time1 = time.process_time()

print('------------------------------------------------------------------------------')
print('64 x 64 Unit square')
print('k_eff                                                   :', solver.eigval)
print('Number of iterations Dynamic Power Method with momentum :', solver.power_its)
print('CPU time                                                 :', time1 - time0) 

print('------------------------------------------------------------------------------')
# Crear el dominio
domain = mesh.create_unit_cube(MPI.COMM_WORLD, 16, 16,16)

# Crear el solver y resolver 
solver = NeutronTransportSolver(domain, bord_cond = 'dir')
time0 = time.process_time()
solver.solve()
time1 = time.process_time()

print('16 x 36 Unit square')
print('k_eff                                                   :', solver.eigval)
print('Number of iterations Dynamic Power Method with momentum :', solver.power_its)
print('CPU time                                                :', time1 - time0)

print('------------------------------------------------------------------------------')
# Crear el dominio
domain = mesh.create_unit_cube(MPI.COMM_WORLD, 32, 32,32)
# Crear el solver y resolver 
solver = NeutronTransportSolver(domain,bord_cond = 'dir')
time0 = time.process_time()
solver.solve()
time1 = time.process_time()
print('32 x 32 Unit square')
print('k_eff                                                   :', solver.eigval)
print('Number of iterations Dynamic Power Method with momentum :', solver.power_its)
print('CPU time                                                :', time1 - time0)

# print('------------------------------------------------------------------------------')
# # Crear el dominio
# domain = mesh.create_unit_cube(MPI.COMM_WORLD, 64, 64,64)

# # Crear el solver y resolver 
# solver = NeutronTransportSolver(domain,bord_cond = 'dir')
# time0 = time.process_time()

# solver.solve()
# time1 = time.process_time()

# print('64 x 64 Unit square')
# print('k_eff                                                   :', solver.eigval)
# print('Number of iterations Dynamic Power Method with momentum :', solver.power_its)
# print('CPU time                                                :', time1 - time0)
# Out:
# ------------------------------------------------------------------------------
# prom iteraciones gmres:  10.0
# ------------------------------------------------------------------------------
# 64 x 64 Unit square
# k_eff                                                   : 0.009445715132458978
# Number of iterations Dynamic Power Method with momentum : 11
# CPU time                                                 : 0.8720770180002546
# ------------------------------------------------------------------------------
# prom iteraciones gmres:  20.0
# 16 x 36 Unit square
# k_eff                                                   : 0.009894914857242648
# Number of iterations Dynamic Power Method with momentum : 9
# CPU time                                                : 7.208731876999991
# ------------------------------------------------------------------------------
# prom iteraciones gmres:  32.357142857142854
# 32 x 32 Unit square
# k_eff                                                   : 0.010013005404091509
# Number of iterations Dynamic Power Method with momentum : 16
# CPU time                                                : 420.0633595339996

# %%
1/0.009894
# Out:
# 101.07135637760258

# %%
def gen_power_it_dynamic_momentum(A, B, v0, tol=1e-8, max_iter=1000):
    '''
    Dynamic power itetration with momentum to solver the generalized eigenvalue problem Ax = lambda Bx

    Input:
    - A  petc.mat
    - B, spd  petc.mat
    - v0 petc.vec

    Output:
    - lambda: largest eigenvalue,  multiplication factor
    - x: eigenvector corresponding to the largest eigenvalue
    - k: number of iterations
    - res: residuals list
    '''
    res = []

    ksp = PETSc.KSP().create(A.getComm())
    ksp.setOperators(B)
    ksp.setType('gmres')
    ksp.getPC().setType('gamg')
    ksp.setTolerances(rtol=1e-8, max_it =1000)
    ksp.setFromOptions()
    ksp.setUp()

    v   = B.createVecRight()
    rhs = A.createVecLeft()
    Ax = A.createVecLeft()
    Bx = B.createVecLeft()
    #r    = A.createVecLeft()

    def Bnorm(x):
        y = B.createVecLeft()
        B.mult(x, y)
        q = x.dot(y)                       
        return float(np.sqrt(q))

    
    def solve_B(rhs, y):
        '''
        Preconditioned lineal solver
        '''
        y.set(0.0)
        ksp.solve(rhs, y)
        return y

    # Inicialización
    h0 = Bnorm(v0)
    x0 = v0.copy()
    x0.scale(1.0/h0)
    #rhs = A.createVecLeft()
    A.mult(x0, rhs)    
    #v   = B.createVecRight()     
    v1_vec = solve_B(rhs,v)

    # k = 0 ----------------------------------

    # h1
    h1 = Bnorm(v1_vec)

    # x1
    x_km1 = v1_vec.copy()
    x_km1.scale(1.0/h1)

    # lambda1
    #Ax = A.createVecLeft()
    A.mult(x_km1, Ax)
    Bx = B.createVecLeft()
    B.mult(x_km1, Bx)
    lam1 = float((x_km1.dot(Ax)/x_km1.dot(Bx)))

    #d1
    r = Ax.copy()
    #r.copy(Ax)
    r.axpy(-lam1, Bx)
    d_prev = r.norm()
    res.append(d_prev)

    if d_prev < tol: 
        return lam1, x_km1, 1, res

    # v1
    #rhs = A.createVecLeft()
    A.mult(x_km1, rhs)
    v2_vec = solve_B(rhs,v)

    # k = 1 --------------------------------

    #h2
    h_k = Bnorm(v2_vec)
    x_k = v2_vec.copy()
    x_k.scale(1.0/h_k)

    # lambda 2
    #Ax = A.createVecLeft()
    A.mult(x_k, Ax)
    #Bx = B.createVecLeft()
    B.mult(x_k, Bx)
    lam_k = float((x_k.dot(Ax)/x_k.dot(Bx)))

    #d2 residual
    r = Ax.copy()
    #r.copy(Ax)
    r.axpy(-lam_k, Bx)
    d_k = r.norm()
    res.append(d_k)
    if d_k < tol: 
        return lam_k, x_k, 2, res

    # redefine parameters
    r_k = min(d_k/d_prev, 1.0)
    k = 2

    # k >= 2 --------------------------------------------------

    while k < max_iter:

        # beta_k
        beta_k = (lam_k**2) * (r_k**2) / 4.0

        #v_{k+1}
        #rhs = A.createVecLeft()
        A.mult(x_k, rhs)
        v_kp1 = solve_B(rhs,v) 

        # u_{k+1}
        u_kp1 = v_kp1.copy()
        u_kp1.axpy(-(beta_k / h_k), x_km1)

        # h_{k+1}
        h_kp1 = Bnorm(u_kp1)

        # x_{k+1}
        x_kp1 = u_kp1.copy()
        x_kp1.scale(1.0/h_kp1)

        # lambda_{k+1}
        #Ax = A.createVecLeft()
        A.mult(x_kp1, Ax)
        #Bx = B.createVecLeft()
        B.mult(x_kp1, Bx)
        lam_kp1 = float((x_kp1.dot(Ax) / x_kp1.dot(Bx)))

        # d_{k+1}
        r = Ax.copy()
        #r.copy(Ax)
        r.axpy(-lam_kp1, Bx)
        d_kp1 = r.norm()
        res.append(d_kp1)
        if d_kp1 < tol: 
            return lam_kp1, x_kp1, k+1, res

        # rho_k
        rho_k = min(d_k/d_prev, 1.0)

        #r_{k+1}
        r_k = 2.0*rho_k/(1.0 + rho_k**2)

        #Update parameters
        x_km1 = x_k
        x_k = x_kp1
        h_k = h_kp1
        d_prev = d_k
        d_k =  d_kp1
        lam_k = lam_kp1
        k += 1

    return lam_k, x_k, k, res

# %%
def gen_power_it_dynamic_momentum(A, B, v0, tol=1e-8, max_iter=1000):
    '''
    Dynamic power itetration with momentum to solver the generalized eigenvalue problem Ax = lambda Bx

    Input:
    - A  petc.mat
    - B, spd  petc.mat
    - v0 petc.vec

    Output:
    - lambda: largest eigenvalue,  multiplication factor
    - x: eigenvector corresponding to the largest eigenvalue
    - k: number of iterations
    - res: residuals list
    '''
    res = []

    ksp = PETSc.KSP().create(A.getComm())
    ksp.setOperators(B)
    ksp.setType('gmres')
    ksp.getPC().setType('gamg')
    ksp.setTolerances(rtol=1e-8, max_it =1000)
    ksp.setFromOptions()
    ksp.getIterationNumber()
    ksp.setUp()

    v   = B.createVecRight()
    rhs = A.createVecLeft()
    Ax = A.createVecLeft()
    Bx = B.createVecLeft()
    v_kp1 = A.createVecLeft()
    u_kp1 = v_kp1.copy()
    x_kp1 = u_kp1.copy()
    v1_vec = A.createVecLeft()
    v2_vec = A.createVecLeft()
    #r    = A.createVecLeft()
    
    y = B.createVecLeft()

    # Inicialización
    B.mult(v0, v)
    q = v.dot(v0)                       
    h0 = float(np.sqrt(q))
    x0 = v0.copy()
    x0.scale(1.0/h0)
    #rhs = A.createVecLeft()
    A.mult(x0, rhs)    
    #v   = B.createVecRight()    
    ksp.solve(rhs, v1_vec)

    # k = 0 ----------------------------------

    # h1
    #Bnorm(v1_vec, h1)
    B.mult(v1_vec, v)
    q = v.dot(v1_vec)                       
    h1 = float(np.sqrt(q))
    x1 = v1_vec.copy()

    # x1
    x_km1 = v1_vec.copy()
    x_km1.scale(1.0/h1)

    # lambda1
    #Ax = A.createVecLeft()
    A.mult(x_km1, Ax)
    
    B.mult(x_km1, Bx)
    lam1 = float((x_km1.dot(Ax)))

    #d1
    r = Ax.copy()
    #r.copy(Ax)
    r.axpy(-lam1, Bx)
    d_prev = r.norm()
    res.append(d_prev)

    if d_prev < tol: 
        return lam1, x_km1, 1, res

    # v1
    #rhs = A.createVecLeft()
    A.mult(x_km1, rhs)

    #A.mult(x_k, rhs)
    ksp.solve(rhs, v2_vec)

    # k = 1 --------------------------------

    #h2
    B.mult(v2_vec, v)
    q = v.dot(v2_vec)                       
    h_k = float(np.sqrt(q))
    x_k = v2_vec.copy()
    x_k.scale(1.0/h_k)

    # lambda 2
    #Ax = A.createVecLeft()
    A.mult(x_k, Ax)
    #Bx = B.createVecLeft()
    B.mult(x_k, Bx)
    lam_k = float((x_k.dot(Ax)))

    #d2 residual
    r = Ax.copy()
    #r.copy(Ax)
    r.axpy(-lam_k, Bx)
    d_k = r.norm()
    res.append(d_k)
    if d_k < tol: 
        return lam_k, x_k, 2, res

    # redefine parameters
    r_k = min(d_k/d_prev, 1.0)
    k = 2

    # k >= 2 --------------------------------------------------

    while k < max_iter:

        # beta_k
        beta_k = (lam_k**2) * (r_k**2) / 4.0

        #v_{k+1}
        #rhs = A.createVecLeft()
        A.mult(x_k, rhs)
        ksp.solve(rhs, v_kp1)
        #v_kp1 = solve_B(rhs,v) 

        # u_{k+1}
        #u_kp1 = v_kp1.copy()
        v_kp1.copy(u_kp1)
        u_kp1.axpy(-(beta_k / h_k), x_km1)

        # h_{k+1}
        B.mult(u_kp1, y)
        q = u_kp1.dot(y)   
        h_kp1 = float(np.sqrt(q))  

        # x_{k+1}
        u_kp1.copy(x_kp1)
        x_kp1.scale(1.0/h_kp1)

        # lambda_{k+1}
        A.mult(x_kp1, Ax)
        lam_kp1 = float((x_kp1.dot(Ax)))

        # d_{k+1}
        B.mult(x_kp1, Bx)
        Ax.axpy(-lam_kp1, Bx)
        d_kp1 = Ax.norm()
        res.append(d_kp1)
        if d_kp1 < tol: 
            return lam_kp1, x_kp1, k+1, res

        # rho_k
        rho_k = min(d_k/d_prev, 1.0)

        #r_{k+1}
        r_k = 2.0*rho_k/(1.0 + rho_k**2)

        #Update parameters
        x_k.copy(x_km1)
        x_kp1.copy(x_k)
        h_k = h_kp1
        d_prev = d_k
        d_k =  d_kp1
        lam_k = lam_kp1
        k += 1

    return lam_k, x_k, k, res

# %%
from mpi4py import MPI
from dolfinx import *
from dolfinx import mesh, fem, default_scalar_type
import numpy as np
from dolfinx.fem.petsc import assemble_matrix
from mshr import *
import basix, ufl, os
import scipy as sp
from slepc4py import SLEPc

class NeutronTransportSolver:
    '''
    Solver two group for the Neutron transport equation at steady state.
    This solver calculates the multiplication factor and the 2D or 3D fluxes for the thermal and fast group.
    Input:
    - Domain: mesh
    - Equation constants: D1, D2, Sa1, Sa2, nusigf1, nusigf2, S12
    - k: orden of polinomials used for the afinite element aproximation

    '''
    def __init__(
            self,
            domain,
            D1 = 1.0, D2 = 0.5,
            Sa1 = 0.2, Sa2 = 0.1,
            nusigf1 = 0.3, nusigf2 = 0.1,
            S12 = 0.1,
            k = 1,
            bord_cond = 'dir' ,
            eigmethod = 'powerit'     
    ):
        self.domain = domain
        self.D1, self.D2 = D1, D2
        self.Sa1, self.Sa2 = Sa1, Sa2
        self.nusigf1, self.nusigf2 = nusigf1, nusigf2
        self.S12 = S12
        self.k = k
        self.bord_cond = bord_cond
        self.eigmethod = eigmethod

        self.V = self._function_space()
        self.eigval = None
        self.vr = None
        self.vi = None
        self.phi1 = None
        self.phi2 = None
        self.phi1_list = None
        self.phi2_list = None
        self.a = None
        self.f = None

    def _function_space(self):
        H = basix.ufl.element("Lagrange", self.domain.basix_cell(), self.k)
        Vm = basix.ufl.mixed_element([H,H])
        V = fem.functionspace(self.domain, Vm)
        return V
    
    def solve(self):
        phi1, phi2 = ufl.TrialFunctions(self.V)
        v1, v2 = ufl.TestFunctions(self.V)

        dx = ufl.dx

        #Formas bilineales A y F
        A = self.D1 * ufl.inner(ufl.grad(phi1), ufl.grad(v1)) *dx
        A+= (self.Sa1 + self.S12) * phi1 * v1 *dx
        A+= self.D2 * ufl.inner(ufl.grad(phi2), ufl.grad(v2)) *dx
        A+= self.Sa2 * phi2 * v2*dx
        A-= self.S12 * phi1 * v2 * dx

        F = (self.nusigf1 * phi1 * v1 + self.nusigf2 * phi2 * v1) * dx

        def boundary_all(x):
            return np.full(x.shape[1], True, dtype=bool)

        if self.bord_cond == 'dir':  
            boundary_facets = mesh.locate_entities_boundary(self.domain, 
                                                            self.domain.topology.dim - 1, boundary_all)
            boundary_dofs_x = fem.locate_dofs_topological(self.V.sub(0), 
                                                          self.domain.topology.dim - 1, boundary_facets)
            boundary_dofs_x2 = fem.locate_dofs_topological(self.V.sub(1), 
                                                           self.domain.topology.dim - 1, boundary_facets)

            bcx = fem.dirichletbc(default_scalar_type(0), boundary_dofs_x, self.V.sub(0))
            bc1x = fem.dirichletbc(default_scalar_type(0), boundary_dofs_x2, self.V.sub(1))
            bcs = [bc1x, bcx]
        elif self.bord_cond == 'neu':
            bcs = []
        else:
            raise ValueError("Condición de borde inexistente: debe ser 'dir' o 'neu'")

        #ensamble del sistema
        a = assemble_matrix(fem.form(A), bcs = bcs, diagonal = 1e2)
        a.assemble()
        f = assemble_matrix(fem.form(F), bcs = bcs, diagonal = 1e-2)
        f.assemble()
        self.a = a
        self.f = f

        v0 =self.a.createVecLeft()
        v0.set(1.0)
        if self.eigmethod == 'powerit':
            lam_k, x_k, k, res = gen_power_it_dynamic_momentum(self.f, self.a, v0, tol = 1e-8, max_iter = 1000)
            self.eigval = lam_k
            self.power_its = k
            self.vec = x_k
            self.power_res = res

            phi = fem.Function(self.V)
            phi.x.array[:] = self.vec.array
            phi1, phi2 = phi.split()
            V0 = fem.functionspace(self.domain, ('CG', 1))

            self.phi1_proj = fem.Function(V0)
            self.phi1_proj.interpolate(fem.Expression(phi1, V0.element.interpolation_points()))

            self.phi2_proj = fem.Function(V0)
            self.phi2_proj.interpolate(fem.Expression(phi2, V0.element.interpolation_points()))
        if self.eigmethod == 'slepc':
                  # cálculo de vvalores y vectores propios
            print('aca')
            eigensolver = SLEPc.EPS().create(MPI.COMM_WORLD)
            eigensolver.setDimensions(1)
            eigensolver.setProblemType(SLEPc.EPS.ProblemType.GNHEP)

            st = SLEPc.ST().create(MPI.COMM_WORLD)
            st.setType(SLEPc.ST.Type.SINVERT)
            st.setShift(1.0)
            st.setFromOptions()
            eigensolver.setST(st)
            eigensolver.setOperators(a, f)
            eigensolver.setFromOptions()

            eigensolver.solve()

            self.vr, self.vi = a.getVecs()
  
            lam = eigensolver.getEigenpair(0, self.vr, self.vi)
            print('aca2')
            self.eigval = lam

            phi = fem.Function(self.V)
            phi.x.array[:] = self.vr.array

            phi1, phi2 = phi.split()
            V0 = fem.functionspace(self.domain, ("CG", 1))

            self.phi1_proj = fem.Function(V0)
            self.phi1_proj.interpolate(fem.Expression(
                phi1, V0.element.interpolation_points()))
        

            self.phi2_proj = fem.Function(V0)
            self.phi2_proj.interpolate(fem.Expression(
                phi2, V0.element.interpolation_points()))



    def phi_norms(self, num = 0):
        phi1_norm = np.sqrt(fem.assemble_scalar(fem.form(ufl.inner(self.phi1_proj) * ufl.dx)))
        phi2_norm = np.sqrt(fem.assemble_scalar(fem.form(ufl.inner(self.phi2_proj) * ufl.dx)))

        return phi1_norm, phi2_norm
    
    def export(self, name = 'result'):
        
        path = f"outputs/{name}"
        if MPI.COMM_WORLD.rank == 0 and not os.path.exists(path):
            os.makedirs(path)

        with io.VTKFile(MPI.COMM_WORLD, f"{path}/phi1_proj.pvd", "w") as vtk:
            vtk.write_function(self.phi1_proj)

        with io.VTKFile(MPI.COMM_WORLD, f"{path}/phi2_proj.pvd", "w") as vtk:
            vtk.write_function(self.phi2_proj)

        MPI.COMM_WORLD.Barrier()
        if MPI.COMM_WORLD.rank == 0:
            print("Archivos guardados en: ", path)

# %%
# Crear el dominio
domain = mesh.create_unit_square(MPI.COMM_WORLD, 16, 16)

# Crear el solver y resolver 
solver = NeutronTransportSolver(domain)
time0 = time.process_time()
solver.solve()
time1 = time.process_time()

print('------------------------------------------------------------------------------')
print('16 x 36 Unit square')
print('k_eff                                                   :', solver.eigval)
print('Number of iterations Dynamic Power Method with momentum :', solver.power_its)
print('CPU time                                                :', time1 - time0)

# Crear el dominio
domain = mesh.create_unit_square(MPI.COMM_WORLD, 32, 32)

# Crear el solver y resolver 
solver = NeutronTransportSolver(domain)
time0 = time.process_time()
solver.solve()
time1 = time.process_time()

print('------------------------------------------------------------------------------')
print('32 x 32 Unit square')
print('k_eff                                                   :', solver.eigval)
print('Number of iterations Dynamic Power Method with momentum :', solver.power_its)
print('CPU time                                                :', time1 - time0)

# Crear el dominio
domain = mesh.create_unit_square(MPI.COMM_WORLD, 64, 64)

# Crear el solver y resolver 
solver = NeutronTransportSolver(domain)
time0 = time.process_time()
solver.solve()
time1 = time.process_time()

print('------------------------------------------------------------------------------')
print('64 x 64 Unit square')
print('k_eff                                                   :', solver.eigval)
print('Number of iterations Dynamic Power Method with momentum :', solver.power_its)
print('CPU time                                                :', time1 - time0)

# Crear el dominio
domain = mesh.create_unit_square(MPI.COMM_WORLD, 128, 128)

# Crear el solver y resolver 
solver = NeutronTransportSolver(domain)
time0 = time.process_time()
solver.solve()
time1 = time.process_time()

print('------------------------------------------------------------------------------')
print('64 x 64 Unit square')
print('k_eff                                                   :', solver.eigval)
print('Number of iterations Dynamic Power Method with momentum :', solver.power_its)
print('CPU time                                                 :', time1 - time0)
# Out:
# ------------------------------------------------------------------------------
# 16 x 36 Unit square
# k_eff                                                   : 0.014878728578009578
# Number of iterations Dynamic Power Method with momentum : 9
# CPU time                                                : 0.03764853600000606
# ------------------------------------------------------------------------------
# 32 x 32 Unit square
# k_eff                                                   : 0.014985003833863333
# Number of iterations Dynamic Power Method with momentum : 9
# CPU time                                                : 0.10079547899999852
# ------------------------------------------------------------------------------
# 64 x 64 Unit square
# k_eff                                                   : 0.0150117668388303
# Number of iterations Dynamic Power Method with momentum : 6
# CPU time                                                : 0.3540985060000139
# Abort is in progress...hit ctrl-c again within 5 seconds to forcibly terminate
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 52
#      50 solver = NeutronTransportSolver(domain)
#      51 time0 = time.process_time()
# ---> 52 solver.solve()
#      53 time1 = time.process_time()
#      55 print('------------------------------------------------------------------------------')
#
# Cell In[32], line 103, in NeutronTransportSolver.solve(self)
#     101 v0.set(1.0)
#     102 if self.eigmethod == 'powerit':
# --> 103     lam_k, x_k, k, res = gen_power_it_dynamic_momentum(self.f, self.a, v0, tol = 1e-8, max_iter = 1000)
#     104     self.eigval = lam_k
#     105     self.power_its = k
#
# Cell In[31], line 127, in gen_power_it_dynamic_momentum(A, B, v0, tol, max_iter)
#     124 #v_{k+1}
#     125 #rhs = A.createVecLeft()
#     126 A.mult(x_k, rhs)
# --> 127 ksp.solve(rhs, v_kp1)
#     128 #v_kp1 = solve_B(rhs,v)
#     129
#     130 # u_{k+1}
#     131 #u_kp1 = v_kp1.copy()
#     132 v_kp1.copy(u_kp1)
#
# KeyboardInterrupt:
